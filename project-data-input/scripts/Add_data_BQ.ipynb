# %% [markdown]
# # Add informacion a Big Query

# %%
import pandas as pd
import os
import json
from datetime import datetime
import pytz
from dotenv import load_dotenv
from google.cloud import bigquery
import pandas_gbq

pd.set_option("display.max_columns", None)

# %%
load_dotenv()

project_id = os.getenv("GCP_PROJECT_ID")
dataset_id = os.getenv("BQ_DATASET_ID")
table_id = os.getenv("BQ_TABLE_ID")
credentials_path = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

print("Proyecto:", project_id)
print("Dataset:", dataset_id)
print("Tabla:", table_id)
print("Credencial:", credentials_path)
# Out:
# Proyecto: gcp-data-bigquery-prod-us-east
# Dataset: hist_table
# Tabla: input_data
# Credencial: secrets/SA-gcp-data-bigquery-prod-us-east-8ef5fac44549.json

# %%
# Periodo
AAAAMM = '202606'

# %%
df = pd.read_csv('./data/raw/test.csv', sep = ',')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
with open("./scripts/rename_columns.json", "r", encoding="utf-8") as archivo:
    dictRename = json.load(archivo)
print(type(dictRename))
print(dictRename)
# Out:
# <class 'dict'>
# ...

# %%
df = df.rename(columns=dictRename)
df.dtypes
# Out:
# id                 int64
# mssubclass         int64
# mszoning          object
# lotfrontage      float64
# lotarea            int64
#                   ...
# miscval            int64
# mosold             int64
# yrsold             int64
# saletype          object
# salecondition     object
# Length: 80, dtype: object

# %%
ZPeru = pytz.timezone("America/Lima")
fecha_carga = datetime.now(ZPeru)
df['date_subida_local'] = fecha_carga.replace(tzinfo=None)
df['date_subida_utc'] = fecha_carga.astimezone(pytz.UTC)
df['periodo'] = AAAAMM

colOrden = ['id','periodo'] + [col for col in df.columns if col not in ('id','periodo')]

df = df[colOrden]

df.head()
# Out:
#      id periodo  mssubclass mszoning  lotfrontage  lotarea street alley  \
# 0  1461  202606          20       RH         80.0    11622   Pave   NaN
# 1  1462  202606          20       RL         81.0    14267   Pave   NaN
# 2  1463  202606          60       RL         74.0    13830   Pave   NaN
# 3  1464  202606          60       RL         78.0     9978   Pave   NaN
# 4  1465  202606         120       RL         43.0     5005   Pave   NaN
#
#   lotshape landcontour utilities lotconfig landslope neighborhood condition  \
# 0      Reg         Lvl    AllPub    Inside       Gtl        NAmes     Feedr
# 1      IR1         Lvl    AllPub    Corner       Gtl        NAmes      Norm
# 2      IR1         Lvl    AllPub    Inside       Gtl      Gilbert      Norm
# 3      IR1         Lvl    AllPub    Inside       Gtl      Gilbert      Norm
# 4      IR1         HLS    AllPub    Inside       Gtl      StoneBr      Norm
#
#   condition_secundaria bldgtype housestyle  overallqual  overallcond  \
# ...

# %%
destination_table = f"{dataset_id}.{table_id}"
full_table_id = f"{project_id}.{destination_table}"
print(destination_table)

client = bigquery.Client(project=project_id)

cantidad_esperada = len(df)


query_delete = f"""
    DELETE FROM `{full_table_id}` WHERE periodo = '{AAAAMM}'
"""
print("Ejecutando DELETE TABLE...")

delete_job = client.query(query_delete)
delete_job.result()

print(f"Tabla vaciada correctamente para el periodo {AAAAMM}✅")

print("Iniciando carga del DataFrame...")

pandas_gbq.to_gbq(df , destination_table, if_exists='append', project_id=project_id)

print("Proceso de carga finalizado.")

# ---------------------------------------
# Out:
# hist_table.input_data
# Ejecutando DELETE TABLE...
# Tabla vaciada correctamente para el periodo 202606✅
# Iniciando carga del DataFrame...
# Proceso de carga finalizado.
